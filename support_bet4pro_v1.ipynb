# %%
import telebot
from telebot import types


token='5139872325:AAHOuVVlkZxbFZAhXCMklXzJJ8V1ZKKSXjg'
bot = telebot.TeleBot(token)


#Создаём кучу констант взятых из таблицы
start_mes = '''Здравствуйте, выберите язык
Hello, select a language'''

start_btn = ['RU', 'ENG']

w_help = ['С чем вам нужна помощь?', 'What do you need help with? ']

keyboard_ru = ['Ставка', 'Аккаунт', 'Депозит', 'Вывод', 'Маркет', 'Сотрудничество']
keyboard_eng = ['Bet', 'Account', 'Deposit', 'Withdraw', 'Market', 'Cooperation']

deposit_method = ['Чем вы пользовались для ввода?', 'What did you use to deposit?']
wd_metod = ['Чем вы пользовались для вывода?', 'What did you use for withdrawal?']

b_deposit_ru = ['Скинами', 'Платежной системой']
b_deposit_eng = ['Items', 'Payment system']
b_withdraw_ru = ['Скинами', 'Платежной системой']
b_withdraw_eng = ['Items', 'Payment system']

bet_ru = 'Прошу детально описать вашу проблему и написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/'
bet_eng = 'Please, describe your problem and send your ID from this page http://bets4.net/profile/  '

account_ru = 'Прошу детально описать вашу проблему и написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/'
account_eng = 'Please, describe your problem and send your ID from this page http://bets4.net/profile/  '

dep_items_ru = 'Прошу написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/ и Protection code вашего обмена, который прошел с ошибкой. Все трейды можно посмотреть по ссылке https://bets4.net/ru/payments/?history во вкладке история.'
dep_items_eng = 'Please, send your ID from this page http://bets4.net/profile/  and Protection code (in text form) of the failed trade. All the trades can be found at https://bets4.me/payments/ history tab.'
dep_ps_ru = 'Прошу детально описать вашу проблему, написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/ и ID вашего пополнения. Все пополнения можно посмотреть по ссылке https://bets4.net/ru/payments/?history во вкладке история.'
dep_ps_eng = 'Please describe your problem, write your ID, you can find it in your profile here http://bets4.net/profile/ and your deposit ID. All deposits can be viewed at the link https://bets4.net/payments/?history in the history tab.'

wd_items_ru = 'Прошу написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/ и Protection code вашего обмена, который прошел с ошибкой. Все трейды можно посмотреть по ссылке https://bets4.net/ru/payments/?history во вкладке история.'
wd_items_eng = 'Please, send your ID from this page http://bets4.net/profile/ and Protection code (in text form) of the failed trade. All the trades can be found at https://bets4.me/payments/?history history tab.'
wd_ps_ru = 'Если максимальный срок вывода еще не прошел, то скорее всего ваш вывод в норме и находится в процессе обработки. Сроки вывода указаны для каждого из способов вывода на странице https://bets4.net/payments/?withdraw Если же максимальный срок уже прошел или вы допустили ошибку в реквизитах, прошу написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/ и ID вашего вывода. Все выводы можно посмотреть по ссылке https://bets4.net/ru/payments/?history во вкладке история.'
wd_ps_eng = 'If the maximum withdrawal period has not yet passed, then most likely your withdrawal is fine and is being processed. Withdrawal periods are indicated for each of the withdrawal methods on the page https://bets4.net/payments/?withdraw If the maximum period has already passed or you made a mistake in the details, please describe your problem, write your ID, you can find it in your profile at the link http://bets4.net/profile/ and your withdrawal ID. All withdrawals can be viewed at the link https://bets4.net/payments/?history in the history tab.'

market_ru = 'Прошу детально описать вашу проблему и написать ваш ID, его можно узнать в профиле по ссылке http://bets4.net/ru/profile/'
market_eng = 'Please, describe your problem and send your ID from this page http://bets4.net/profile/'

cooperation_ru = 'Напишите пожалуйста подробности вашего предложения (цены, форматы рекламы, ссылку на ваш ресурс). '
cooperation_eng = 'Please provide details of your offer? (prices, format of the advertisment, link for your channel/website/group)'

#Реакция бота на /start
@bot.message_handler(commands=['start'])
def start(message):
    
    markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
             
    item1 = types.KeyboardButton(start_btn[0])
    markup.add(item1)
    
    item2 = types.KeyboardButton(start_btn[1])
    markup.add(item2)
    
    bot.send_message(message.chat.id, start_mes, reply_markup=markup)

    
@bot.message_handler(content_types='text')
def keyboard_call(message):
    
    #Создаём клавиатуру для ру юзеров
    if message.text == start_btn[0]:
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)
             
        b1 = types.KeyboardButton(keyboard_ru[0])
        b2 = types.KeyboardButton(keyboard_ru[1])
        b3 = types.KeyboardButton(keyboard_ru[2])
        b4 = types.KeyboardButton(keyboard_ru[3])
        b5 = types.KeyboardButton(keyboard_ru[4])
        b6 = types.KeyboardButton(keyboard_ru[5])
        
        markup.row(b1, b2, b3)
        markup.row(b4, b5, b6)

        bot.send_message(message.chat.id, w_help[0], reply_markup=markup)
        
    #Создаём клавиатуру для англ юзеров   
    elif message.text == start_btn[1]:
        markup = types.ReplyKeyboardMarkup(resize_keyboard=True)

        b1 = types.KeyboardButton(keyboard_eng[0])
        b2 = types.KeyboardButton(keyboard_eng[1])
        b3 = types.KeyboardButton(keyboard_eng[2])
        b4 = types.KeyboardButton(keyboard_eng[3])
        b5 = types.KeyboardButton(keyboard_eng[4])
        b6 = types.KeyboardButton(keyboard_eng[5])
        
        markup.row(b1, b2, b3)
        markup.row(b4, b5, b6)

        bot.send_message(message.chat.id, w_help[1], reply_markup=markup)
    
    #Реакция на 'Ставка'
    elif message.text == keyboard_ru[0]:
        bot.send_message(message.chat.id, bet_ru)
   
    #Реакция на 'Bet'      
    elif message.text == keyboard_eng[0]:
        bot.send_message(message.chat.id, bet_eng)
    
    #Реакция на 'Аккаунт'       
    elif message.text == keyboard_ru[1]:
        bot.send_message(message.chat.id, account_ru)
    
    #Реакция на 'Account'  
    elif message.text == keyboard_eng[1]:
        bot.send_message(message.chat.id, account_eng)
    
    #Реакция на 'Депозит'    
    elif message.text == keyboard_ru[2]:
        markup = types.InlineKeyboardMarkup()
        
        button_items = types.InlineKeyboardButton('Скинами', callback_data='dep_items_ru')
        button_ps = types.InlineKeyboardButton('Платежной системой', callback_data='dep_ps_ru')
       
        markup.add(button_items)
        markup.add(button_ps)
        
        bot.send_message(message.chat.id, deposit_method[0], reply_markup=markup)
    
    #Реакция на 'Deposit'    
    elif message.text == keyboard_eng[2]:
        markup = types.InlineKeyboardMarkup()
        
        button_items = types.InlineKeyboardButton('Items', callback_data='dep_items_eng')
        button_ps = types.InlineKeyboardButton('Payment system', callback_data='dep_ps_eng')
       
        markup.add(button_items)
        markup.add(button_ps)
        
        bot.send_message(message.chat.id, deposit_method[1], reply_markup=markup)
    
    #Реакция на 'Вывод'    
    elif message.text == keyboard_ru[3]:
        markup = types.InlineKeyboardMarkup()
        
        button_items = types.InlineKeyboardButton('Скинами', callback_data='wd_items_ru')
        button_ps = types.InlineKeyboardButton('Платежной системой', callback_data='wd_ps_ru')
       
        markup.add(button_items)
        markup.add(button_ps)
        
        bot.send_message(message.chat.id, wd_metod[0], reply_markup=markup)
        
    #Реакция на 'Withdraw'    
    elif message.text == keyboard_eng[3]:
        markup = types.InlineKeyboardMarkup()
        
        button_items = types.InlineKeyboardButton('Items', callback_data='wd_items_eng')
        button_ps = types.InlineKeyboardButton('Payment system', callback_data='wd_ps_eng')
       
        markup.add(button_items)
        markup.add(button_ps)
        
        bot.send_message(message.chat.id, wd_metod[1], reply_markup=markup)
        
    #Реакция на 'Маркет'  
    elif message.text == keyboard_ru[4]:
        bot.send_message(message.chat.id, market_ru)
        
    #Реакция на 'Market'  
    elif message.text == keyboard_eng[4]:
        bot.send_message(message.chat.id, market_eng)
        
    #Реакция на 'Сотрудничество'  
    elif message.text == keyboard_ru[5]:
        bot.send_message(message.chat.id, cooperation_ru)
        
    #Реакция на 'Cooperation'  
    elif message.text == keyboard_eng[5]:
        bot.send_message(message.chat.id, cooperation_eng)
        
        
        
@bot.callback_query_handler(func=lambda call: True)            
def callback_worker(call):
    
    #Реакция на 'Скинами' dep
    if call.data == "dep_items_ru": 
        bot.send_message(call.message.chat.id, dep_items_ru)
    
    #Реакция на 'Платежной системой' dep
    elif call.data == "dep_ps_ru":
         bot.send_message(call.message.chat.id, dep_ps_ru)
            
    #Реакция на 'Items' dep       
    elif call.data == "dep_items_eng":
         bot.send_message(call.message.chat.id, dep_items_eng)
    
    #Реакция на 'Payment system' dep
    elif call.data == "dep_ps_eng":
         bot.send_message(call.message.chat.id, dep_ps_eng)
            
    #Реакция на 'Скинами' wd
    elif call.data == "wd_items_ru":
         bot.send_message(call.message.chat.id, wd_items_ru)
            
    #Реакция на 'Платежной системой' wd
    elif call.data == "wd_ps_ru":
         bot.send_message(call.message.chat.id, wd_items_ru)
            
    #Реакция на 'Items' wd
    elif call.data == "wd_items_eng":
         bot.send_message(call.message.chat.id, wd_items_eng)
            
    #Реакция на 'Payment system' wd
    elif call.data == "wd_ps_eng":
         bot.send_message(call.message.chat.id, wd_ps_eng)


        
bot.polling(none_stop=True, interval=0)
